# %% [markdown]
# ### Tools

# %% [markdown]
# Models can request to call tools that perform tasks sunch as fetching data from a database, searching the web, or running code. Tools are pairing of:
#
# 1. A schema, including the name of the tool, a description, and /or argument definitons(often a JSON schema)
# 2. A function or corutine to execute.
